# %% [markdown]
# <a href="https://colab.research.google.com/github/77marco/Challenge-Data-Science-Alura/blob/main/AluraStoreLatam_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
 import pandas as pd

 url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
 url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
 url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
 url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
# Calcular la facturación (suma de precios) para cada tienda
facturacion_1 = tienda['Precio'].sum()
facturacion_2 = tienda2['Precio'].sum()
facturacion_3 = tienda3['Precio'].sum()
facturacion_4 = tienda4['Precio'].sum()

# Imprimir los resultados
print(f"Facturación Tienda 1: ${facturacion_1}")
print(f"Facturación Tienda 2: ${facturacion_2}")
print(f"Facturación Tienda 3: ${facturacion_3}")
print(f"Facturación Tienda 4: ${facturacion_4}")

# Opcional: Si quieres saber el total de todas las tiendas juntas
total_general = facturacion_1 + facturacion_2 + facturacion_3 + facturacion_4
print(f"---")
print(f"Facturación Total Global: ${total_general}")
# Out:
# Facturación Tienda 1: $1150880400.0
# Facturación Tienda 2: $1116343500.0
# Facturación Tienda 3: $1098019600.0
# Facturación Tienda 4: $1038375700.0
# ---
# Facturación Total Global: $4403619200.0

# %% [markdown]
# # 2. Ventas por categoría

# %%
# Se Calcula y se cuentan las ventas por categoría para cada tienda
# value_counts() ordena automáticamente de la categoría más vendida a la menos vendida

print("--- Tienda 1: Ventas por Categoría ---")
print(tienda['Categoría del Producto'].value_counts())
print("\n")

print("--- Tienda 2: Ventas por Categoría ---")
print(tienda2['Categoría del Producto'].value_counts())
print("\n")

print("--- Tienda 3: Ventas por Categoría ---")
print(tienda3['Categoría del Producto'].value_counts())
print("\n")

print("--- Tienda 4: Ventas por Categoría ---")
print(tienda4['Categoría del Producto'].value_counts())
# Out:
# --- Tienda 1: Ventas por Categoría ---
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64
#
#
# --- Tienda 2: Ventas por Categoría ---
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64
#
#
# --- Tienda 3: Ventas por Categoría ---
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
# Calcular la calificación promedio para cada tienda
promedio_1 = tienda['Calificación'].mean()
promedio_2 = tienda2['Calificación'].mean()
promedio_3 = tienda3['Calificación'].mean()
promedio_4 = tienda4['Calificación'].mean()

# Imprimir los resultados redondeados a 2 decimales para que se vea ordenado
print(f"Calificación Promedio Tienda 1: {promedio_1:.2f}")
print(f"Calificación Promedio Tienda 2: {promedio_2:.2f}")
print(f"Calificación Promedio Tienda 3: {promedio_3:.2f}")
print(f"Calificación Promedio Tienda 4: {promedio_4:.2f}")
# Out:
# Calificación Promedio Tienda 1: 3.98
# Calificación Promedio Tienda 2: 4.04
# Calificación Promedio Tienda 3: 4.05
# Calificación Promedio Tienda 4: 4.00

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
# Función para analizar y mostrar extremos de ventas
def mostrar_extremos(df, nombre_tienda):
    conteo = df['Producto'].value_counts()
    mas_vendido = conteo.index[0]
    menos_vendido = conteo.index[-1]

    print(f"--- {nombre_tienda} ---")
    print(f"Más vendido: {mas_vendido} ({conteo.iloc[0]} ventas)")
    print(f"Menos vendido: {menos_vendido} ({conteo.iloc[-1]} ventas)")
    print("")

# Ejecutar para las 4 tiendas
mostrar_extremos(tienda, "Tienda 1")
mostrar_extremos(tienda2, "Tienda 2")
mostrar_extremos(tienda3, "Tienda 3")
mostrar_extremos(tienda4, "Tienda 4")
# Out:
# --- Tienda 1 ---
# Más vendido: Microondas (60 ventas)
# Menos vendido: Celular ABXY (33 ventas)
#
# --- Tienda 2 ---
# Más vendido: Iniciando en programación (65 ventas)
# Menos vendido: Juego de mesa (32 ventas)
#
# --- Tienda 3 ---
# Más vendido: Kit de bancas (57 ventas)
# Menos vendido: Bloques de construcción (35 ventas)
#
# --- Tienda 4 ---
# Más vendido: Cama box (62 ventas)
# Menos vendido: Guitarra eléctrica (33 ventas)

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
# Calculo del costo de envío promedio para cada tienda
envio_promedio_1 = tienda['Costo de envío'].mean()
envio_promedio_2 = tienda2['Costo de envío'].mean()
envio_promedio_3 = tienda3['Costo de envío'].mean()
envio_promedio_4 = tienda4['Costo de envío'].mean()

# Se imprimen los resultados formateados
print(f"Envío Promedio Tienda 1: ${envio_promedio_1:.2f}")
print(f"Envío Promedio Tienda 2: ${envio_promedio_2:.2f}")
print(f"Envío Promedio Tienda 3: ${envio_promedio_3:.2f}")
print(f"Envío Promedio Tienda 4: ${envio_promedio_4:.2f}")
# Out:
# Envío Promedio Tienda 1: $26018.61
# Envío Promedio Tienda 2: $25216.24
# Envío Promedio Tienda 3: $24805.68
# Envío Promedio Tienda 4: $23459.46

# %% [markdown]
# # Generando gráficos

# %%
import matplotlib.pyplot as plt

# --- PREPARACIÓN DE DATOS ---
# Se crean listas con los resultados de tus ejercicios anteriores para graficar
tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
ingresos = [facturacion_1, facturacion_2, facturacion_3, facturacion_4]
envios_promedio = [envio_promedio_1, envio_promedio_2, envio_promedio_3, envio_promedio_4]
# Datos para el gráfico de pastel (Se usa Tienda 1 como ejemplo representativo)
categorias_t1 = tienda['Categoría del Producto'].value_counts()

# Configuración del tamaño de la figura (Ancho, Alto)
plt.figure(figsize=(18, 5))

# --- GRÁFICO 1: DE BARRAS (INGRESOS POR TIENDA) ---
plt.subplot(1, 3, 1) # (1 fila, 3 columnas, posición 1)
plt.bar(tiendas, ingresos, color=['#4CAF50', '#2196F3', '#FF9800', '#9C27B0'])
plt.title('Ingresos Totales por Tienda')
plt.ylabel('Monto ($)')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# --- GRÁFICO 2: DE PASTEL (CATEGORÍAS - TIENDA 1) ---
plt.subplot(1, 3, 2) # (Posición 2)
plt.pie(categorias_t1, labels=categorias_t1.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribución de Ventas por Categoría (Tienda 1)')

# --- GRÁFICO 3: BARRAS HORIZONTALES (COSTO DE ENVÍO PROMEDIO) ---
plt.subplot(1, 3, 3) # (Posición 3)
plt.barh(tiendas, envios_promedio, color='#FF5722')
plt.title('Costo de Envío Promedio')
plt.xlabel('Costo ($)')
plt.grid(axis='x', linestyle='--', alpha=0.7)

# Ajustar espacio entre gráficos y mostrar
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Informe final**

# %% [markdown]
# ##**Análisis de Desempeño de Tiendas Alura Store**
#
# 1. **Introducción**
#
# El objetivo de este análisis fue evaluar el desempeño de cuatro tiendas (Tienda 1, 2, 3 y 4) para proporcionar una recomendación basada en datos al Sr. Juan sobre qué decisión estratégica tomar con sus activos. Se analizaron factores clave como facturación total, satisfacción del cliente (calificaciones), costos de envío y distribución de categorías.
#
# 2. **Desarrollo y Hallazgos**
#
# A través del procesamiento de datos y la visualización gráfica, se encontraron los siguientes puntos clave:
#
# Ingresos (Facturación): Existe una clara disparidad en los ingresos.
# La Tienda 1 lidera la facturación, posicionándose como el activo financiero más fuerte. En contraste, la Tienda 4 presenta el rendimiento más bajo.
#
# Satisfacción del Cliente: Aunque la Tienda 1 vende más, su calidad percibida es la más baja, con un promedio de 3.98. La Tienda 3 destaca por la excelencia en servicio, alcanzando la mayor calificación promedio (4.05), seguida muy de cerca por la Tienda 2.
#
# Costos Operativos (Envíos): Los costos promedio de envío se mantienen estables entre las cuatro sucursales (alrededor de $24,000 - $26,000), por lo que no es un factor diferenciador negativo para ninguna tienda en particular.
#
# Productos: Las categorías "Electrónicos" y "Muebles" dominan las ventas, siendo los motores principales de ingreso en todas las sucursales.
#
# 3. **Conclusión y Recomendación**
#
# Basado en el análisis comparativo, se presentan dos escenarios para la decisión del Sr. Juan:
#
# **Recomendación Principal:** Vender la Tienda 4
# Si el objetivo es optimizar la cartera de negocios eliminando el eslabón más débil, se recomienda vender la Tienda 4.
#
# **Justificación:** Es la tienda con menores ingresos totales, facturando significativamente menos que la líder. Además, su calificación de satisfacción es promedio, sin destacar en excelencia como la Tienda 3 ni en volumen como la Tienda 1.
#
# **Nota Estratégica sobre la Tienda 1:** Aunque es la que más factura, se debe prestar atención urgente a su satisfacción al cliente (la más baja del grupo), ya que esto podría afectar las ventas a largo plazo.

# %% [markdown]
# ## **Extra. Análisis del desempeño geográfico**

# %% [markdown]
# ##**Código análisis desempeño geográfico**

# %%
# Se verifica cuántas coordenadas válidas (no vacías) tiene cada tienda
print("--- Cantidad de coordenadas válidas por tienda ---")
print(datos_geo.groupby('Nombre_Tienda')[['lat', 'lon']].count())

# Se verifica una muestra de las coordenadas para ver si son idénticas
print("\n--- Muestra de coordenadas ---")
print(datos_geo[['Nombre_Tienda', 'lat', 'lon']].head())
# Out:
# --- Cantidad de coordenadas válidas por tienda ---
#                 lat   lon
# Nombre_Tienda
# Tienda 1       2359  2359
# Tienda 2       2359  2359
# Tienda 3       2359  2359
# Tienda 4       2358  2358
#
# --- Muestra de coordenadas ---
#   Nombre_Tienda       lat       lon
# 0      Tienda 1   4.60971 -74.08175
# 1      Tienda 1   6.25184 -75.56359
# 2      Tienda 1  10.39972 -75.51444
# 3      Tienda 1   3.43722 -76.52250
# 4      Tienda 1   6.25184 -75.56359

# %%
import matplotlib.pyplot as plt

# Configuración: Crear una cuadrícula de 2 filas x 2 columnas de gráficos
fig, axs = plt.subplots(2, 2, figsize=(15, 10))
fig.suptitle('Distribución Geográfica por Tienda (Vistas Separadas)', fontsize=16)

# Definimos coordenadas de los ejes para cada tienda (fila, columna)
posiciones = [(0, 0), (0, 1), (1, 0), (1, 1)]
tiendas_lista = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
colores_lista = ['#4CAF50', '#2196F3', '#FF9800', '#9C27B0']

# Bucle para dibujar cada tienda en su propio cuadro
for i, nombre in enumerate(tiendas_lista):
    fila, col = posiciones[i]
    ax = axs[fila, col]

    # Filtramos datos solo de esa tienda
    datos = datos_geo[datos_geo['Nombre_Tienda'] == nombre]

    # Dibujamos
    ax.scatter(datos['lon'], datos['lat'], color=colores_lista[i], alpha=0.5, s=20)
    ax.set_title(nombre)
    ax.set_xlabel('Longitud')
    ax.set_ylabel('Latitud')
    ax.grid(True, linestyle='--', alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##**Conclusiones del Análisis Geográfico**
#
# Al mapear las coordenadas (lat y lon) de las ventas para cada tienda por separado, se identificó el siguiente patrón:
#
# **Distribución Idéntica**: Las cuatro tiendas presentan exactamente la misma dispersión geográfica. Los puntos de venta se concentran en las mismas coordenadas específicas, sin variaciones entre una sucursal y otra.
#
# **Mercado Compartido**: No existen territorios exclusivos. Todas las tiendas compiten directamente en las mismas zonas geográficas, abarcando las mismas regiones sin distinción (norte, sur o centro).
#
# **Impacto en el Rendimiento**: Dado que la ubicación es una variable constante para todas, se concluye que el bajo rendimiento de la Tienda 4 no se debe a una mala ubicación geográfica, sino a factores operativos (como la gestión de inventario o atención al cliente), ya que opera exactamente en los mismos lugares que la Tienda 1 (la líder en ventas).
